# %% [markdown]
# **Лабораторная работа курса компьютерной графики**
#
# **Задание:**
# Согласно варианту заданий, приведенных в приложении 2,
# построить двумерное изображение заданной фигуры.
# Над фигурой выполнить все аффинные преобразования:
# перенос, отражение, масштабирование, поворот

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
"""
Изобразим заданную фигуру на координатной сетке
"""
# Объявим матрицу, содержащую координаты фигуры 
A = [
[-2.5, -2.2, 1],  
[-1.8, 4, 1], 
[2, 1.5, 1],
[-1, -2.2, 1],
[-1.2, 0, 1],
[-2.5, -2.2, 1]
]

# %%
# Теперь сформируем массив Numpy, которому передадим объявленную на предыдущем шаге матрицу А
A = np.array(A)

# %%
# Соберем значения координат, по которым следом построим plot-визуализацию
x = A[:,0]   
y = A[:,1]

# %%
# Оформляем визуализацию
fig, ax = plt.subplots()
# реализуем построение осей координат
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
# на плоскости изобразим график
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()
plt.ylim([-5, 5])
plt.xlim([-5, 5])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(-1.3, 2.1, 'Исходная фигура',
        rotation = -24,
        fontsize = 12)
ax.set_title('Рис.1. Отправной график')
plt.show()

# %%
"""
Сместим матрицу относительно ее центра в точке Q(x=-0.25, y=0.9) на данный вектор
"""

Q = np.array([
[1, 0, 0],
[0, 1, 0],
[0.25, -0.9, 1],
])

# %%
vectorized_matrix = A@Q
x = vectorized_matrix[:,0]
y = vectorized_matrix[:,1]

# %%
# Оформляем визуализацию
fig, ax = plt.subplots()
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()
plt.ylim([-5, 5])
plt.xlim([-5, 5])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(0.2, -3.5, 'Смещение\n центра',
        rotation = 35,
        fontsize = 12)
ax.set_title('Рис.2. График с фигурой,\n смещенной по своему центру')
plt.show()
vectorized_matrix
# Out:
# array([[-2.25, -3.1 ,  1.  ],
#        [-1.55,  3.1 ,  1.  ],
#        [ 2.25,  0.6 ,  1.  ],
#        [-0.75, -3.1 ,  1.  ],
#        [-0.95, -0.9 ,  1.  ],
#        [-2.25, -3.1 ,  1.  ]])

# %%
"""
Осуществим масштабирование заданной фигуры
"""

# Определим масштабирующую матрицу 
B = np.array([
[2, 0, 0],
[0, 2, 0],
[0, 0, 1],
])

# %%
# Масштабирование осуществим через перемножение матриц 
reduce_2_times = A@B       # reduce_2_times = np.dot(A,B)
x = reduce_2_times[:,0]
y = reduce_2_times[:,1]

# %%
# Оформляем визуализацию
fig, ax = plt.subplots()
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()

plt.ylim([-9, 9])
plt.xlim([-9, 9])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(-1, -6, 'Масштабированная\n фигура',
        rotation = 37,
        fontsize = 12)
ax.set_title('Рис.3. График с фигурой,\n в 2 раза увеличенной')
plt.show()
reduce_2_times
# Out:
# array([[-5. , -4.4,  1. ],
#        [-3.6,  8. ,  1. ],
#        [ 4. ,  3. ,  1. ],
#        [-2. , -4.4,  1. ],
#        [-2.4,  0. ,  1. ],
#        [-5. , -4.4,  1. ]])

# %%
"""
Осуществим поворот заданной фигуры на 130 градусов
"""
# объявим матрицу поворота
C = np.array([
[math.cos(math.radians(100)), math.sin(math.radians(100)), 0],
[math.sin(math.radians(100)), math.cos(math.radians(100)), 0],
[0,0,1]
])

# %%
rotation_matrix = A@C

# %%
# Соберем значения координат, по которым следом построим plot-визуализацию
x = rotation_matrix[:,0]
y = rotation_matrix[:,1]

# %%
# Оформляем визуализацию
fig, ax = plt.subplots()
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()
# Определим диапазон сетки графика
plt.ylim([-5, 5])
plt.xlim([-5, 5])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(1.3, -1.3, 'Развернутая фигура',
        rotation = -42,
        fontsize = 12)
# Добавляем заголовок
ax.set_title('Рис.4. График с исходной фигурой,\n повернутой на 100 градусов по обеим осям')
plt.show()
rotation_matrix
# Out:
# array([[-1.73245661, -2.07999339,  1.        ],
#        [ 4.25179773, -2.46724667,  1.        ],
#        [ 1.12991527,  1.70914324,  1.        ],
#        [-1.99292888, -0.60278176,  1.        ],
#        [ 0.20837781, -1.1817693 ,  1.        ],
#        [-1.73245661, -2.07999339,  1.        ]])

# %%
"""
Осуществим перенос заданной фигуры 
"""

# Определим матрицу переноса 
D = np.array([
[1, 0, 0],
[0, 1, 0],
[2, 2, 1],
])

# %%
transfer_matrix = A@D

# %%
# Соберем значения координат, по которым следом построим plot-визуализацию
x = transfer_matrix[:,0]
y = transfer_matrix[:,1]

# %%
# Оформляем визуализацию
fig, ax = plt.subplots()
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()
# Определим диапазон сетки графика
plt.ylim([-5, 9])
plt.xlim([-5, 5])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(0.5, 4.2, 'Перенесенная фигура',
        rotation = -19,
        fontsize = 12)
# Добавляем заголовок
ax.set_title('Рис.5. График с перенесенной исходной фигурой')
plt.show()
transfer_matrix
# Out:
# array([[-0.5, -0.2,  1. ],
#        [ 0.2,  6. ,  1. ],
#        [ 4. ,  3.5,  1. ],
#        [ 1. , -0.2,  1. ],
#        [ 0.8,  2. ,  1. ],
#        [-0.5, -0.2,  1. ]])

# %%
"""
Осуществим отражение заданной фигуры 
"""

# Определим отражающую матрицу 
E = np.array([
[1, 0, 0],
[0, -1, 0],
[0, 0, 1],
])

# %%
# Сформируем расчет для отраженной матрицы 
reflection_matrix = A@E  
x = transfer_matrix[:,0]
y = transfer_matrix[:,1]

# %%
# Оформим визуализацию
fig, ax = plt.subplots()
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()
# Определим диапазон сетки графика
plt.ylim([-5, 9])
plt.xlim([-5, 5])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(0.5, 4.2, 'Отраженная фигура',
        rotation = -20,
        fontsize = 12)
# Добавляем заголовок
ax.set_title('Рис.6. График с отраженной исходной фигурой')
plt.show()
reflection_matrix
# Out:
# array([[-2.5,  2.2,  1. ],
#        [-1.8, -4. ,  1. ],
#        [ 2. , -1.5,  1. ],
#        [-1. ,  2.2,  1. ],
#        [-1.2,  0. ,  1. ],
#        [-2.5,  2.2,  1. ]])

# %%
"""
Выполним одномоментно все преобразования матрицы
"""
# Объявим матрицу, содержащую координаты фигуры 
A1 = [
[-2.5, -2.2, 1],  
[-1.8, 4, 1], 
[2, 1.5, 1],
[-1, -2.2, 1],
[-1.2, 0, 1],
[-2.5, -2.2, 1]
]

transformation_matrix = A@Q@B@C@D@E
# transformation_matrix = A1@B
x = transfer_matrix[:,0]
y = transfer_matrix[:,1]

# %%
# Оформим визуализацию
fig, ax = plt.subplots()
ax.axhline(y=0, color='k', linewidth = 5)
ax.axvline(x=0, color='k', linewidth = 5)
ax.plot(x, y, color='green', linewidth = 4)
#  Включим второстепенные деления осей
ax.minorticks_on()
# Определим диапазон сетки графика
plt.ylim([-5, 9])
plt.xlim([-5, 5])
# определим внешний вид основной сетки
ax.grid(which='major',color = 'k', linewidth = 1)
#  Определяем внешний вид линий вспомогательной сетки
ax.grid(which='minor', color = 'k', linestyle = ':')
# добавим подпись к графику
#  Добавляем текст:
ax.text(0.5, 4.2, 'Измененная фигура',
        rotation = -20,
        fontsize = 12)
# Добавляем заголовок
ax.set_title('Рис.6. График всех преобразований над фигурой')
plt.show()
transformation_matrix
# Out:
# array([[-3.32439127,  1.35501619,  1.        ],
#        [ 8.64411742,  2.12952274,  1.        ],
#        [ 2.4003525 , -6.22325708,  1.        ],
#        [-3.8453358 , -1.59940707,  1.        ],
#        [ 0.55727758, -0.44143199,  1.        ],
#        [-3.32439127,  1.35501619,  1.        ]])
